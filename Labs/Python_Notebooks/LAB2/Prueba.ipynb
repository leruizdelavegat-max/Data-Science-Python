# %%
import sys, platform
import pandas as pd, selenium
print("Python exe:", sys.executable)
print("Python ver:", platform.python_version())
print("pandas:", pd.__version__)
print("selenium:", selenium.__version__)
# Out:
# Python exe: c:\Users\LENOVO\anaconda3\envs\yelp_scraper\python.exe
# Python ver: 3.10.18
# pandas: 2.2.2
# selenium: 4.31.1
