# %% [markdown]
# ## Macroeconomics
# IMP: log-Commodity price index, TC: log-exchange rate, RIN: log-international reserves, IPC: log-price consumption index, RATE: central bank rate reference
#
# D: Annual difference

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\melor\anaconda3\lib\site-packages (1.44.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (4.25.2)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (4.12.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\melor\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in c:\users\melor\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\melor\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\melor\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.33.0)
# Requirement already satisfied: colorama in c:\users\melor\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\melor\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\melor\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\melor\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\melor\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\melor\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\melor\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\melor\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\melor\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\melor\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\melor\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\melor\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\melor\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<3,>=1.4.0->streamlit) (1.16.0)

# %%
import streamlit as st

st.title("Mi Primera Aplicación con Streamlit")
st.write("¡Hola mundo!")

# Agregar un widget interactivo
nombre = st.text_input("Escribe tu nombre")
if nombre:
    st.write(f"Hola, {nombre}!")
# Out:
# 2025-04-09 03:31:17.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.983 Session state does not function when running a script without `streamlit run`
# 2025-04-09 03:31:17.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:17.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import seaborn as sns
import matplotlib.pyplot as plt

# Configura el estilo de seaborn
sns.set('notebook')

# Crea el gráfico y guarda la referencia
g = sns.relplot(x="YEAR", y="IPM", kind="line", color="red", data=macro, height=5, aspect=2)

# Añade etiquetas y título
plt.xlabel(' ')
plt.ylabel(' ')
plt.title('Índice del precio de materias primas 2013-2019')

# Añade el texto al pie del gráfico
txt="Elboración propia - BCRP"  
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=12)

# Muestra el gráfico en Streamlit
st.pyplot(g.fig)
# Out:
# 2025-04-09 03:31:18.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:19.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:31:19.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# !jupyter nbconvert --to script Train_streamlist.ipynb
# Out:
# [NbConvertApp] Converting notebook Train_streamlist.ipynb to script
# [NbConvertApp] Writing 4331 bytes to Train_streamlist.py

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
macro = pd.read_csv("../../../data/macroeconomia.csv")
macro['YEAR']  = pd.to_datetime(macro['Fecha'])
macro
# Out:
#        Fecha      IPM       TC      RIN       IPC    RATE      DIPM      DTC  \
# 0     2003-1  2.83506  1.25634   9.18519  4.41828  3.7500  13.73166  0.83108
# 1     2003-2  2.85371  1.25004   9.21777  4.42295  3.8000  12.48664  0.16400
# 2     2003-3  2.84717  1.24993   9.24303  4.43407  3.8200   7.76170  0.65330
# 3     2003-4  2.80982  1.24554   9.24188  4.43356  3.8400   1.97256  0.69980
# 4     2003-5  2.88617  1.24686   9.23065  4.43324  3.7800   6.81493  0.92160
# ..       ...      ...      ...       ...      ...     ...       ...      ...
# 199   2019-8  3.74485  1.22252  11.12236  4.88368  2.5642   3.71183  2.73013
# 200   2019-9  3.74443  1.20844  11.12124  4.88375  2.5038   7.63091  1.29986
# 201  2019-10  3.70510  1.20622  11.13029  4.88486  2.5045   0.48716  0.71850
# 202  2019-11  3.69955  1.20500  11.11988  4.88594  2.2984   0.97267 -0.08858
# 203  2019-12  3.73001  1.20204  11.13212  4.88809  2.2501   2.87310 -0.25863
#
#          DRIN     DIPC       YEAR
# 0    12.50532  2.25690 2003-01-01
# 1    13.17984  2.76396 2003-02-01
# 2    17.18115  3.33857 2003-03-01
# 3    13.92729  2.56103 2003-04-01
# 4    12.37214  2.39028 2003-05-01
# ..        ...      ...        ...
# 199  12.37958  2.01920 2019-08-01
# 200  15.82517  1.83408 2019-09-01
# 201  15.12033  1.86310 2019-10-01
# 202  11.80591  1.84959 2019-11-01
# 203  12.80208  1.88227 2019-12-01
#
# [204 rows x 11 columns]

# %%
sns.set('notebook')

sns.relplot(x="YEAR", y="IPM", kind="line", color="red", data=macro, height=5, aspect=2)
plt.xlabel(' ')
plt.ylabel(' ')
plt.title('Índice del precio de materias primas 2013-2019')

txt="Elboración propia - BCRP"  
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=12)
# Out:
# Text(0.5, 0.01, 'Elboración propia - BCRP')

# %% [markdown]
# #### Series in a single image
#
# This graph shows a positive relationship between the change in international reserves and the commodity index.

# %%
sns.set('notebook')


fig, ax = plt.subplots(figsize=(12,5))

x = macro['YEAR']
y1 = macro['DIPM']
y2 = macro['DRIN']

plt.plot(x, y1, label ='Indice de materias primas (Var %)', color='blue')
plt.plot(x, y2, label ='Reservas internacionales (Var %)', color='red')
plt.axhline(y=0, color='black', linestyle='--', lw=0.8)

plt.legend(loc='upper right')

txt="Elaboración propia - BCRP"  
plt.figtext(0.2, 0.01, txt, wrap=True, horizontalalignment='right', fontsize=10)
# Out:
# Text(0.2, 0.01, 'Elaboración propia - BCRP')

# %% [markdown]
# ### Dual-line Plots
#
# #### Exchange rate and monetary policy reaction

# %%
sns.set('notebook', style = "ticks", font_scale= 1.08)

fig, ax = plt.subplots(figsize=(10,5))
lineplot = sns.lineplot(x= "YEAR" , y= "RATE", data=macro, 
                        label = 'Tasa interbancaria promedio ', color="k", legend=False)

#sns.despine()
plt.ylabel('Tasa de política monetaria')
plt.xlabel(' ')
plt.title('Exchange rate and monetary policy reaction');

ax2 = ax.twinx()
lineplot2 = sns.lineplot(x= "YEAR", y= "DTC", data=macro, ax=ax2, color = "red", 
                         label ='Tipo de cambio (variación anual %)', legend=False) 
sns.despine(right=False)
plt.ylabel('Tipo de cambio')
ax.figure.legend(loc='lower center', bbox_to_anchor=(1.1, 0.5), ncol=1);


txt="Elboración propia - BCRP"  
plt.figtext(0.2, 0.01, txt, wrap=True, horizontalalignment='right', fontsize=10)
# Out:
# Text(0.2, 0.01, 'Elboración propia - BCRP')

# %%
# !jupyter nbconvert --to script Train_streamlist.ipynb
# Out:
# [NbConvertApp] Converting notebook Train_streamlist.ipynb to script
# [NbConvertApp] Writing 3435 bytes to Train_streamlist.py

# %%
import streamlit as st
import seaborn as sns
import matplotlib.pyplot as plt

# Configura el estilo de seaborn
sns.set('notebook')

# Crea el gráfico y guarda la referencia
g = sns.relplot(x="YEAR", y="IPM", kind="line", color="red", data=macro, height=5, aspect=2)

# Añade etiquetas y título
plt.xlabel(' ')
plt.ylabel(' ')
plt.title('Índice del precio de materias primas 2013-2019')

# Añade el texto al pie del gráfico
txt="Elboración propia - BCRP"  
plt.figtext(0.5, 0.01, txt, wrap=True, horizontalalignment='center', fontsize=12)

# Muestra el gráfico en Streamlit
st.pyplot(g.fig)
# Out:
# 2025-04-09 03:06:10.279 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:06:11.076 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-09 03:06:11.839
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\melor\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-09 03:06:11.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #### Reference:
#
# #### Library of plots
#
# https://www.python-graph-gallery.com/stacked-and-percent-stacked-barplot
#
# #### Seaborn package:
#
# https://seaborn.pydata.org/generated/seaborn.catplot.html
#
# https://programmerclick.com/article/54791895404/
